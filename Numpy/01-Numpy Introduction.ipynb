# %% [markdown]
# # 01-Numpy Introduction

# %% [markdown]
# ### List - Slow

# %% [markdown]
# ### Numpy - Fast

# %% [markdown]
# Why numpy is faster?

# %% [markdown]
# Numpy is faster because it used fixed types

# %% [markdown]
# #### Advantages of numpy

# %% [markdown]
# 1. Faster to read less bytes of memory.

# %% [markdown]
# 2. No type checking when iterating through objects.

# %% [markdown]
# 3. It uses contigious memory. i.e., all blocks are right next to each other.

# %% [markdown]
# ![Python_Library_-_Numpy_-_page-0001.jpg](attachment:Python_Library_-_Numpy_-_page-0001.jpg)

# %% [markdown]
# #### Application of numpy

# %% [markdown]
# 1. Mathematics(MATLAB replacement)

# %% [markdown]
# 2. Plotting(matplotlib)

# %% [markdown]
# 3. Backend(pandas, connect4,Digital Photography)

# %% [markdown]
# 4. Machine Learning
